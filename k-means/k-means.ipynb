# %%
import sys
from operator import itemgetter
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.cluster import AgglomerativeClustering, KMeans
import numpy as np
import nltk
import re
from nltk import pos_tag
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer, WordNetLemmatizer
from collections import defaultdict
from scipy.spatial import distance
import json
filename = 'Titles.txt'
number_of_clusters = 10

def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return ''

lemmatiser = WordNetLemmatizer()

stemmer = nltk.SnowballStemmer("english")

with open(filename,"r") as f:
	input_text = f.readlines()
f.close()

input_data = []


def tokenize(text):
    lemmatized_words = []
    text = text.lower()
    text = text.strip("\n")
    text = re.sub(r'\\n',' ',text)
    text = re.sub(r'[^\w\s]',' ',text)
    tokens = nltk.word_tokenize(text)
    tokens_pos = pos_tag(tokens)
    count = 0
    for token in tokens:
        pos = tokens_pos[count]
        pos = get_wordnet_pos(pos[1])
        if pos != '':
            lemma = lemmatiser.lemmatize(token, pos)
        else:
            lemma = lemmatiser.lemmatize(token)
        lemmatized_words.append(lemma)
        count+=1
    return lemmatized_words


for row in input_text:
    row = row.strip("\n")
    input_data.append(row)

count_vectorizer = CountVectorizer(encoding="latin-1", stop_words="english", tokenizer=tokenize, analyzer='word')
Tfidf_vectorizer = TfidfVectorizer(encoding="latin-1", use_idf=True, stop_words="english", tokenizer=tokenize, analyzer='word')
vectorizer = TfidfVectorizer(encoding="latin-1", use_idf=True, stop_words="english", tokenizer=tokenize, analyzer='word')
input_freq = Tfidf_vectorizer.fit_transform(input_data).toarray()
input_vector = Tfidf_vectorizer.fit_transform(input_data)

num_clusters = int(number_of_clusters)
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(input_vector)
clusters = clustering_model.fit_predict(input_vector)

count=1
cluster_text = defaultdict(list)
docs_list =[]

#for cluster in clusters:
    #print cluster

count_data = len(input_data)

for i in range(count_data):
    cluster_id = clusters[i]
    doc_id = i+1
    cluster_text[cluster_id].append(doc_id)

cluster_terms = defaultdict(list)

#print("Top terms per cluster:")
centroids = clustering_model.cluster_centers_
order_centroids = centroids.argsort()[:, ::-1]
terms = Tfidf_vectorizer.get_feature_names()
for i in range(num_clusters):
    #print "Cluster %d:" % i,
    for ind in order_centroids[i, :50]:
        #print ' %s' % terms[ind],
        cluster_terms[i].append((ind,terms[ind]))
    #print

cluster_freq = defaultdict(dict)


for cluster_id, terms in cluster_terms.items():
    doc_list = cluster_text[cluster_id]
    term_freq = defaultdict(int)
    for (index, word) in terms:
        term_count = 0
        for doc in doc_list:
            doc_id = doc - 1
            term_count+= input_freq[doc_id][index]
        term_freq[word] = term_count
    cluster_freq[cluster_id] = term_freq

with open('cluster_freq.json', 'w') as f:
    json.dump(cluster_freq, f)


answers = defaultdict(list)
for i in range(num_clusters):
    #print "Cluster %d:" % i
    doc_list = cluster_text[i]
    #print doc_list
    distances = []
    for doc in doc_list:
        doc_id = doc - 1
        doc_vector = input_vector[doc_id]
        v1 = np.array(centroids[i])
        v2 = np.array(doc_vector.toarray())
        distances.append((doc, distance.euclidean(v1, v2)))

    distances.sort(key = itemgetter(1))
    count = len(distances)
    #print count
    for doc_id, dis in distances:
        answers[i].append(('best',input_data[doc_id-1]))
    #if len(distances)>0:
    #	doc_id, dis = distances[0]
    #	answers[i].append(('best',input_data[doc_id-1]))
    #if len(distances)>1:
    #	doc_id, dis = distances[1]
    #	answers[i].append(('best',input_data[doc_id-1]))
    #if len(distances)>2:
    #	doc_id, dis = distances[count-1]
    #	answers[i].append(('worst', input_data[doc_id-1]))
    #if len(distances)>3:
    #	doc_id, dis = distances[count-2]
    #	answers[i].append(('worst',input_data[doc_id-1] ))

print (answers)

with open("output.txt" , "w") as f:
    for key, value2 in answers.iteritems():
        for idx, answer in enumerate(value2):
            output = str(key)+"\t"+answer[1]+"\n"
        f.write(output)
    print ('Success')
# Out:
# defaultdict(<class 'list'>, {0: [('best', '17X18 LD RL LNR .45G  CLE 1000/CS'), ('best', '20X21 LD RL LNR .45G CLE 1000/CS'), ('best', '30X36 LD RL LNR .45G  CLE 250/CS'), ('best', '24X32 LD RL LNR .45G BRO 500/CS'), ('best', '24X23 LD RL LNR .45G  BRO 500/CS'), ('best', '30X42 LD S/HEX FLT BG LNR 2.7G CLE 75/CS'), ('best', '17 X 17 .35 MIL CLEAR 1000/CS'), ('best', '17X17 LD LINER REF WT .4 0MIL 4GAL BLA 1000'), ('best', '19X21 WHITE FILM DRAWTAP E 50BGS/RL 10RL/CASE'), ('best', '13 GAL BIOBAG 24"X28"RETAIL ECO 144 PER CASE')], 1: [('best', '100% RECYCLED PLASTIC GARBAGE BAGS, 33GAL, 1.5MIL, 33 X 40, BROWN/BLACK, 100/CT'), ('best', '100% RECYCLED PLASTIC GARBAGE BAGS, 33GAL, 1.3MIL, 33 X 40, BROWN/BLACK, 100/CT'), ('best', '100% RECYCLED PLASTIC GARBAGE BAGS, 60GAL, 1.5MIL, 36 X 58, BROWN/BLACK, 100/CT'), ('best', '100% RECYCLED PLASTIC GARBAGE BAGS, 40-45GAL, 1.5MIL, 40X48, BROWN/BLACK, 100/CT'), ('best', '100% RECYCLED PLASTIC GARBAGE BAGS, 65GAL, 1.5MIL, 50X51, BROWN/BLACK, 100/CT'), ('best', '100% RECYCLED PLASTIC GARBAGE BAG, 55-60GAL, 1.5MIL, 38X60, BROWN/BLACK, 100/CT'), ('best', '100% RECYCLED PLASTIC GARBAGE BAGS, 56GAL, 1.5MIL, 43 X 49, BROWN/BLACK, 100/CT'), ('best', '100% RECYCLED PLASTIC GARBAGE BAGS, 20-30GAL, 1.3MIL, 30X39, BROWN/BLACK, 100/CT'), ('best', '100% RECYCLED PLASTIC GARBAGE BAGS, 7-10GAL, 1MIL, 24 X 24, BROWN/BLACK, 250/CT')], 2: [('best', '30X36 LD LINER HVY .65GA  20-30GAL CLE 250'), ('best', '30X36 LD LINER HVY .65GA  20-30GAL CLE 250'), ('best', '30X36 LD PERF CORELESS R L HVY .65GA 20-30GAL BLA'), ('best', '30X36 LD PERF CORELESS R L MED .65GA 20-30GAL CLE'), ('best', '30X36 LD RL LNR HVY .7GA  20-30GAL GRA 250'), ('best', '30X36 LD RL LNR MED .50G A 20-30GAL CLE 10/25'), ('best', '30X36 LD RL LNR X-HVY .8  MIL 20-30GAL WHI 8/25'), ('best', '24X23 LD RL LNR MED .50G A 10GAL GRA 500'), ('best', '30X43 LD HEALTHCARE PRTD  SUPR TUF 1.0GA 20-30GAL')], 3: [('best', '24X32 LD PERF CORELESS R L .35GA BLA 500/CS'), ('best', '24X32 LD PERF CORELESS R L .35GA CLE 500/CS'), ('best', '24X32 LD PERF CORELESS R L .90GA BLA 250/CS'), ('best', '24X32 LD PERF CORELESS R L HVY .9GA 12-16GAL BLA'), ('best', '30X36 LD PERF CORELESS R L .65GA BLA 250/CS'), ('best', '30X36 LD PERF CORELESS R L .45GA BLA 250/CS'), ('best', '20X21 LD PERF CORELESS R L .35GA BLA 1000/CS'), ('best', '24X32 LD PERF CORELESS R L MED .50GA 12-16GAL CLE'), ('best', '24X32 LD PERF CORELESS R L LT WT .45GA 12-16GAL B'), ('best', '29X44 LD PERF CORELESS R L .95GA CLE 100/CS'), ('best', '30X36 LD PERF CORELESS R L 1.0GA GRA 100'), ('best', '24X23 LD PERF CORELESS R L LT WT 8-10GAL CLE 20/5'), ('best', '24X32 LD PERF CORELESS RL 70GA CLEAR 250/CS'), ('best', '30X37 HD PERF CORELESS R L 16MIC 20-30GAL NAT 250'), ('best', '24X32 LD LNR .35GA 16GAL  CLE 500'), ('best', '24X32 LD LNR .9GA 12-16G AL BLA 250'), ('best', '24X32 LD LINER LT WT .35 GA 12-16GAL BRO 1000')], 4: [('best', '2-PLY LOW-DENSITY CAN LINERS, 16GAL, .6MIL, 24 X 33, BLACK, 500/CARTON'), ('best', '2-PLY LOW-DENSITY CAN LINERS, 16GAL, 0.9 MIL, 24 X 32, BLACK, 500/CARTON'), ('best', '2-PLY LOW-DENSITY CAN LINERS, 7-10GAL, .6MIL, 24 X 23, BLACK, 500/CARTON'), ('best', '2-PLY LOW-DENSITY CAN LINERS, 30GAL, .71 MIL, 30 X 36, BLACK, 250/CARTON'), ('best', '2-PLY LOW-DENSITY CAN LINERS, 56GAL, .9 MIL, 43 X 47, BLACK, 100/CARTON'), ('best', '2-PLY LOW-DENSITY CAN LINERS, 31-33GAL, .63 MIL, 33 X 39, BLACK, 250/CARTON'), ('best', '2-PLY LOW-DENSITY CAN LINERS, 40-45GAL, .63 MIL, 40 X 46, BLACK, 250/CARTON'), ('best', '2-PLY LOW-DENSITY CAN LINERS, 55-60GAL, .9MIL, 38 X 58, BLACK, 100/CARTON'), ('best', '"THANK YOU" HANDLED T-SHIRT BAGS, 11 1/2 X 21, POLYETHYLENE, WHITE, 900/CARTON')], 5: [('best', '30X36 LD REPRO FLT BG  LNR 1.5G BLA 250/CS'), ('best', '24X33 LD REPRO FLT BG  LNR 1.5G BLA 250/CS'), ('best', '30X36 LD REPRO FLT BG LNR 2.0G BLA 250/CS'), ('best', '30X36 LD REPRO RL LNR  1.3G BLA 100/CS'), ('best', '30X36 LD RL LNR 1.5G 20- 30GL BLA 200/CASE'), ('best', '24X32 LD RL LNR 1.0G BLA ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-024130758581> in <module>()
#     156
#     157 with open("output.txt" , "w") as f:
# --> 158     for key, value2 in answers.iteritems():
#     159         for idx, answer in enumerate(value2):
#     160             output = str(key)+"\t"+answer[1]+"\n"
#
# AttributeError: 'collections.defaultdict' object has no attribute 'iteritems'
